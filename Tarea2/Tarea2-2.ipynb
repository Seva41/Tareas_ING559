# %% [markdown]
# ## Tarea 2 - Métodos de Aprendizajes de Máquinas en Data Science
#
# ### Integrantes: Sofía Álvarez, Sebastián Dinator.

# %%
# Importando librerías
import pandas as pd
import numpy as np
from sympy import Matrix
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Graficos
from plotnine import ggplot
from plotnine import *

# %%
# Generales
import pandas as pd
import numpy as np
from sympy import Matrix
from plotnine import *

# Imagen
from IPython.display import Image

# Gráficos 
import seaborn as sns
import matplotlib.pyplot as plt

# k-fold cross validation
from sklearn.model_selection import KFold

# Muestreo
from sklearn.model_selection import train_test_split

# Regresión Logística

from sklearn.linear_model import LogisticRegression

# Naive Bayes
from sklearn.naive_bayes import GaussianNB

# Arbol de desicion
from sklearn.tree import DecisionTreeClassifier

# Medidad de tendencia central
import statistics


from sklearn.neighbors import KNeighborsClassifier

# OTROS(?)
import statsmodels.api as sm 
from sklearn.metrics import (confusion_matrix, accuracy_score, precision_score)

# %%
# Importando la data
df = pd.read_csv("trainData.csv")
df
# Out:
#         Unnamed: 0        date  fligth_number origin destination  distance  \
# 0           389083  2009-11-09           8995    BBA         SCL      1394
# 1           177073  2009-05-23           7061    LIM         TRU       489
# 2          1040357  2011-05-09           8972    SCL         PUQ      2180
# 3           505258  2010-02-12           6039    CGH         CNF       524
# 4           369663  2009-10-24           7713    GPS         GYE      1170
# ...            ...         ...            ...    ...         ...       ...
# 999885      359783  2009-10-16           6024    UDI         CGH       552
# 999886      152315  2009-05-03           6669    LIM         HAV      3934
# 999887     1000747  2011-04-04           9094    IQQ         SCL      1430
# 999888      117952  2009-04-04           7704    GYE         SCY      1091
# 999889      305711  2009-09-02           7746    UIO         GYE       283
#
#         noshow  denied_boarding  pax_midlow  pax_high  ...  pax_freqflyer  \
# 0          9.0                0          94         2  ...             22
# 1          0.0                0         100         4  ...             25
# 2          4.0                0           7         1  ...              2
# 3         13.0                0          54         4  ...              4
# 4         14.0                0          21        88  ...              0
# ...        ...              ...         ...       ...  ...            ...
# 999885     5.0                0          25        12  ...             12
# 999886     4.0                0         129         3  ...              2
# 999887     5.0                0           2         1  ...             20
# 999888     2.0                0          67         2  ...             16
# 999889    10.0                0          72         1  ...              2
#
#         group_bookings  out_of_stock  dom_cnx  int_cnx  p2p  departure_time  \
# 0                   19             0        1        0  239        10:30:00
# 1                    0             0       19        9  192        19:20:00
# 2                    0             0        0       10   69        09:54:00
# 3                    0             0       26        0   64        21:00:00
# 4                   88             1       23        3  183        12:40:00
# ...                ...           ...      ...      ...  ...             ...
# 999885               0             0       64        9    0        15:14:00
# 999886              20             0        0      118  156        08:50:00
# 999887              36             0        7        0  124        14:18:00
# 999888               0             0       34        2   98        08:05:00
# 999889               0             0        5        3  119        17:35:00
#
#         capacity revenues_usd  bookings
# 0          174.0      10631.1       240
# 1          174.0       5453.7       220
# 2          218.0      16161.0        79
# 3          174.0      10828.7        90
# 4          144.0      16721.6       209
# ...          ...          ...       ...
# 999885     144.0      14102.1        73
# 999886     168.0      32907.8       274
# 999887     218.0      13519.3       131
# 999888     144.0       8729.6       134
# 999889     144.0       3031.0       127
#
# [999890 rows x 22 columns]

# %% [markdown]
# # Limpieza y selección de variables
#
# ## Analizando la prescencia de nulos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999890 entries, 0 to 999889
# Data columns (total 22 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       999890 non-null  int64
#  1   date             999890 non-null  object
#  2   fligth_number    999890 non-null  int64
#  3   origin           999890 non-null  object
#  4   destination      999890 non-null  object
#  5   distance         999890 non-null  int64
#  6   noshow           999890 non-null  float64
#  7   denied_boarding  999890 non-null  int64
#  8   pax_midlow       999890 non-null  int64
#  9   pax_high         999890 non-null  int64
#  10  pax_midhigh      999890 non-null  int64
#  11  pax_low          999890 non-null  int64
#  12  pax_freqflyer    999890 non-null  int64
#  13  group_bookings   999890 non-null  int64
#  14  out_of_stock     999890 non-null  int64
#  15  dom_cnx          999890 non-null  int64
#  16  int_cnx          999890 non-null  int64
#  17  p2p              999890 non-null  int64
#  18  departure_time   998472 non-null  object
#  19  capacity         999890 non-null  float64
#  20  revenues_usd     999890 non-null  float64
#  21  bookings         999890 non-null  int64
# dtypes: float64(3), int64(15), object(4)
# memory usage: 167.8+ MB

# %%
#date
#origin
#destination
#departure time


df = df.drop(['date', 'origin', 'destination', 'departure_time'], axis = 1)
df
df = df.dropna() # Eliminamos datos nulos.
df = df.reset_index()
#df = df.drop(['level_0', 'index'], axis = 1)
df.shape
display(df)
# Out:
#          index  Unnamed: 0  fligth_number  distance  noshow  denied_boarding  \
# 0            0      389083           8995      1394     9.0                0
# 1            1      177073           7061       489     0.0                0
# 2            2     1040357           8972      2180     4.0                0
# 3            3      505258           6039       524    13.0                0
# 4            4      369663           7713      1170    14.0                0
# ...        ...         ...            ...       ...     ...              ...
# 999885  999885      359783           6024       552     5.0                0
# 999886  999886      152315           6669      3934     4.0                0
# 999887  999887     1000747           9094      1430     5.0                0
# 999888  999888      117952           7704      1091     2.0                0
# 999889  999889      305711           7746       283    10.0                0
#
#         pax_midlow  pax_high  pax_midhigh  pax_low  pax_freqflyer  \
# 0               94         2           28       94             22
# 1              100         4            4       87             25
# 2                7         1            5       64              2
# 3               54         4            7       21              4
# 4               21        88           18       82              0
# ...            ...       ...          ...      ...            ...
# 999885          25        12           20        4             12
# 999886         129         3           19      121              2
# 999887           2         1            0      108             20
# 999888          67         2            7       42             16
# 999889          72         1            1       51              2
#
#         group_bookings  out_of_stock  dom_cnx  int_cnx  p2p  capacity  \
# 0                   19             0        1        0  239     174.0
# 1                    0             0       19        9  192     174.0
# 2                    0             0        0       10   69     218.0
# 3                    0             0       26        0   64     174.0
# 4                   88             1       23        3  183     144.0
# ...                ...           ...      ...      ...  ...       ...
# 999885               0             0       64        9    0     144.0
# 999886              20             0        0      118  156     168.0
# 999887              36             0        7        0  124     218.0
# 999888               0             0       34        2   98     144.0
# 999889               0             0        5        3  119     144.0
#
#         revenues_usd  bookings
# 0            10631.1       240
# 1             5453.7       220
# 2            16161.0        79
# 3            10828.7        90
# 4            16721.6       209
# ...              ...       ...
# 999885       14102.1        73
# 999886       32907.8       274
# 999887       13519.3       131
# 999888        8729.6       134
# 999889        3031.0       127
#
# [999890 rows x 19 columns]

# %%
for columna in df.columns:
    if type(df[columna][0]) != str:
        print(columna.upper())
        print(len(df[columna].unique()))
        display(df[df[columna]%1 != 0])
# Out:
# INDEX
# 999890
# Empty DataFrame
# Columns: [index, Unnamed: 0, fligth_number, distance, noshow, denied_boarding, pax_midlow, pax_high, pax_midhigh, pax_low, pax_freqflyer, group_bookings, out_of_stock, dom_cnx, int_cnx, p2p, capacity, revenues_usd, bookings]
# Index: []
# UNNAMED: 0
# 999890
# Empty DataFrame
# Columns: [index, Unnamed: 0, fligth_number, distance, noshow, denied_boarding, pax_midlow, pax_high, pax_midhigh, pax_low, pax_freqflyer, group_bookings, out_of_stock, dom_cnx, int_cnx, p2p, capacity, revenues_usd, bookings]
# Index: []
# FLIGTH_NUMBER
# 4026
# Empty DataFrame
# Columns: [index, Unnamed: 0, fligth_number, distance, noshow, denied_boarding, pax_midlow, pax_high, pax_midhigh, pax_low, pax_freqflyer, group_bookings, out_of_stock, dom_cnx, int_cnx, p2p, capacity, revenues_usd, bookings]
# Index: []
# DISTANCE
# 754
# Empty DataFrame
# Columns: [index, Unnamed: 0, fligth_number, distance, noshow, denied_boarding, pax_midlow, pax_high, pax_midhigh, pax_low, pax_freqflyer, group_bookings, out_of_stock, dom_cnx, int_cnx, p2p, capacity, revenues_usd, bookings]
# Index: []
# NOSHOW
# 115
# Empty DataFrame
# Columns: [index, Unnamed: 0, fligth_number, distance, noshow, denied_boarding, pax_midlow, pax_high, pax_midhigh, pax_low, pax_freqflyer, group_bookings, out_of_stock, dom_cnx, int_cnx, p2p, capacity, revenues_usd, bookings]
# Index: []
# DENIED_BOARDING
# 35
# Empty DataFrame
# Columns: [index, Unnamed: 0, fligth_number, distance, noshow, denied_boarding, pax_midlow, pax_high, pax_midhigh, pax_low, pax_freqflyer, group_bookings, out_of_stock, dom_cnx, int_cnx, p2p, capacity, revenues_usd, bookings]
# Index: []
# PAX_MIDLOW
# 322
# Empty DataFrame
# Columns: [index, Unnamed: 0, fligth_number, distance, noshow, denied_boarding, pax_midlow, pax_high, pax_midhigh, pax_low, pax_freqflyer, group_bookings, out_of_stock, dom_cnx, int_cnx, p2p, capacity, revenues_usd, bookings]
# Index: []
# PAX_HIGH
# 154
# Empty DataFrame
# Columns: [index, Unnamed: 0, fligth_number, distance, noshow, denied_boarding, pax_midlow, pax_high, pax_midhigh, pax_low, pax_freqflyer, group_bookings, out_of_stock, dom_cnx, int_cnx, p2p, capacity, revenues_usd, bookings]
# Index: []
# PAX_MIDHIGH
# 158
# Empty DataFrame
# Columns: [index, Unnamed: 0, fligth_number, distance, noshow, denied_boarding, pax_midlow, pax_high, pax_midhigh, pax_low, pax_freqflyer, group_bookings, out_of_stock, dom_cnx, int_cnx, p2p, capacity, revenues_usd, bookings]
# Index: []
# PAX_LOW
# 278
# Empty DataFrame
# Columns: [index, Unnamed: 0, fligth_number, distance, noshow, denied_boarding, pax_midlow, pax_high, pax_midhigh, pax_low, pax_freqflyer, group_bookings, out_of_stock, dom_cnx, int_cnx, p2p, capacity, revenues_usd, bookings]
# Index: []
# PAX_FREQFLYER
# 214
# Empty DataFrame
# Columns: [index, Unnamed: 0, fligth_number, distance, noshow, denied_boarding, pax_midlow, pax_high, pax_midhigh, pax_low, pax_freqflyer, group_bookings, out_of_stock, dom_cnx, int_cnx, p2p, capacity, revenues_usd, bookings]
# Index: []
# GROUP_BOOKINGS
# 209
# Empty DataFrame
# Columns: [index, Unnamed: 0, fligth_number, distance, noshow, denied_boarding, pax_midlow, pax_high, pax_midhigh, pax_low, pax_freqflyer, group_bookings, out_of_stock, dom_cnx, int_cnx, p2p, capacity, revenues_usd, bookings]
# Index: []
# OUT_OF_STOCK
# 2
# Empty DataFrame
# Columns: [index, Unnamed: 0, fligth_number, distance, noshow, denied_boarding, pax_midlow, pax_high, pax_midhigh, pax_low, pax_freqflyer, group_bookings, out_of_stock, dom_cnx, int_cnx, p2p, capacity, revenues_usd, bookings]
# Index: []
# DOM_CNX
# 220
# Empty DataFrame
# Columns: [index, Unnamed: 0, fligth_number, distance, noshow, denied_boarding, pax_midlow, pax_high, pax_midhigh, pax_low, pax_freqflyer, group_bookings, out_of_stock, dom_cnx, int_cnx, p2p, capacity, revenues_usd, bookings]
# Index: []
# INT_CNX
# 333
# Empty DataFrame
# Columns: [index, Unnamed: 0, fligth_number, distance, noshow, denied_boarding, pax_midlow, pax_high, pax_midhigh, pax_low, pax_freqflyer, group_bookings, out_of_stock, dom_cnx, int_cnx, p2p, capacity, revenues_usd, bookings]
# Index: []
# P2P
# 422
# Empty DataFrame
# Columns: [index, Unnamed: 0, fligth_number, distance, noshow, denied_boarding, pax_midlow, pax_high, pax_midhigh, pax_low, pax_freqflyer, group_bookings, out_of_stock, dom_cnx, int_cnx, p2p, capacity, revenues_usd, bookings]
# Index: []
# CAPACITY
# 232
#          index  Unnamed: 0  fligth_number  distance  noshow  denied_boarding  \
# 1047      1047      437541           5420       590    12.0                0
# 4698      4698      439135           6076      1182     5.0                0
# 13695    13695      447967           5589      1607     6.0                0
# 22619    22619      443874           5792       657     4.0                0
# 27762    27762      440030           5408       590     6.0                0
# ...        ...         ...            ...       ...     ...              ...
# 952284  952284      454335           5844      2446    18.0                0
# 958702  958702      454360           5916       590     3.0                0
# 959324  959324      439988           6079      1182     2.0                0
# 965548  965548      438992           6079      1182    36.0                0
# 989314  989314      441319           6172      1182     2.0                0
#
#         pax_midlow  pax_high  pax_midhigh  pax_low  pax_freqflyer  \
# 1047            83         3            6       54             18
# 4698           110         5            9       89             13
# 13695           86         0            0       76             20
# 22619           46         3           11       33             42
# 27762           84         0            0       53             24
# ...            ...       ...          ...      ...            ...
# 952284          59         0            9       34             26
# 958702          88         0            2       63             10
# 959324         108         0            2       95             15
# 965548          60         0            0       43             14
# 989314         121         0            1      101             14
#
#         group_bookings  out_of_stock  dom_cnx  int_cnx  p2p    capacity  \
# 1047                 0             0       85        2   77  174.294915
# 4698                 0             0       13       26  187  173.705584
# 13695                0             0       13        0  169  174.108276
# 22619                0             1       60        0   75  174.264840
# 27762                1             0       10        5  146  144.244068
# ...                ...           ...      ...      ...  ...         ...
# 952284               0             0        2        1  125  174.142273
# 958702               0             0       57        0  106  174.294915
# 959324               0             0       15        9  196  173.705584
# 965548               0             0       12        3  102  173.705584
# 989314               0             0       17        7  213  173.705584
#
#         revenues_usd  bookings
# 1047         11662.4       164
# 4698         14245.5       226
# 13695         8832.6       182
# 22619         6922.3       135
# 27762         7185.6       161
# ...              ...       ...
# 952284       21221.3       128
# 958702        7709.7       163
# 959324       14357.0       220
# 965548        7842.8       117
# 989314       13139.2       237
#
# [172 rows x 19 columns]
# REVENUES_USD
# 310851
#          index  Unnamed: 0  fligth_number  distance  noshow  denied_boarding  \
# 0            0      389083           8995      1394     9.0                0
# 1            1      177073           7061       489     0.0                0
# 3            3      505258           6039       524    13.0                0
# 4            4      369663           7713      1170    14.0                0
# 5            5      251495           8734      5861     6.0                0
# ...        ...         ...            ...       ...     ...              ...
# 999884  999884      122579           8878      1430     3.0                0
# 999885  999885      359783           6024       552     5.0                0
# 999886  999886      152315           6669      3934     4.0                0
# 999887  999887     1000747           9094      1430     5.0                0
# 999888  999888      117952           7704      1091     2.0                0
#
#         pax_midlow  pax_high  pax_midhigh  pax_low  pax_freqflyer  \
# 0               94         2           28       94             22
# 1              100         4            4       87             25
# 3               54         4            7       21              4
# 4               21        88           18       82              0
# 5              188         4            2       85             20
# ...            ...       ...          ...      ...            ...
# 999884          86         7           51       80              8
# 999885          25        12           20        4             12
# 999886         129         3           19      121              2
# 999887           2         1            0      108             20
# 999888          67         2            7       42             16
#
#         group_bookings  out_of_stock  dom_cnx  int_cnx  p2p  capacity  \
# 0                   19             0        1        0  239     174.0
# 1                    0             0       19        9  192     174.0
# 3                    0             0       26        0   64     174.0
# 4                   88             1       23        3  183     144.0
# 5                    0             0        0       99  200     279.0
# ...                ...           ...      ...      ...  ...       ...
# 999884              39             0      104        5  123     218.0
# 999885               0             0       64        9    0     144.0
# 999886              20             0        0      118  156     168.0
# 999887              36             0        7        0  124     218.0
# 999888               0             0       34        2   98     144.0
#
#         revenues_usd  bookings
# 0            10631.1       240
# 1             5453.7       220
# 3            10828.7        90
# 4            16721.6       209
# 5            81609.3       299
# ...              ...       ...
# 999884       14169.6       232
# 999885       14102.1        73
# 999886       32907.8       274
# 999887       13519.3       131
# 999888        8729.6       134
#
# [899548 rows x 19 columns]
# BOOKINGS
# 581
# Empty DataFrame
# Columns: [index, Unnamed: 0, fligth_number, distance, noshow, denied_boarding, pax_midlow, pax_high, pax_midhigh, pax_low, pax_freqflyer, group_bookings, out_of_stock, dom_cnx, int_cnx, p2p, capacity, revenues_usd, bookings]
# Index: []

# %%
df['capacity'].describe()
# Out:
# count    999890.000000
# mean        178.056881
# std          32.694811
# min          53.000000
# 25%         150.000000
# 50%         174.000000
# 75%         174.000000
# max         451.000000
# Name: capacity, dtype: float64

# %%
eliminar = list(df[df['capacity'] % 1 != 0].index)
data = df.drop(eliminar,axis=0)
data = data.reset_index()
data
# Out:
#         level_0   index  Unnamed: 0  fligth_number  distance  noshow  \
# 0             0       0      389083           8995      1394     9.0
# 1             1       1      177073           7061       489     0.0
# 2             2       2     1040357           8972      2180     4.0
# 3             3       3      505258           6039       524    13.0
# 4             4       4      369663           7713      1170    14.0
# ...         ...     ...         ...            ...       ...     ...
# 999713   999885  999885      359783           6024       552     5.0
# 999714   999886  999886      152315           6669      3934     4.0
# 999715   999887  999887     1000747           9094      1430     5.0
# 999716   999888  999888      117952           7704      1091     2.0
# 999717   999889  999889      305711           7746       283    10.0
#
#         denied_boarding  pax_midlow  pax_high  pax_midhigh  pax_low  \
# 0                     0          94         2           28       94
# 1                     0         100         4            4       87
# 2                     0           7         1            5       64
# 3                     0          54         4            7       21
# 4                     0          21        88           18       82
# ...                 ...         ...       ...          ...      ...
# 999713                0          25        12           20        4
# 999714                0         129         3           19      121
# 999715                0           2         1            0      108
# 999716                0          67         2            7       42
# 999717                0          72         1            1       51
#
#         pax_freqflyer  group_bookings  out_of_stock  dom_cnx  int_cnx  p2p  \
# 0                  22              19             0        1        0  239
# 1                  25               0             0       19        9  192
# 2                   2               0             0        0       10   69
# 3                   4               0             0       26        0   64
# 4                   0              88             1       23        3  183
# ...               ...             ...           ...      ...      ...  ...
# 999713             12               0             0       64        9    0
# 999714              2              20             0        0      118  156
# 999715             20              36             0        7        0  124
# 999716             16               0             0       34        2   98
# 999717              2               0             0        5        3  119
#
#         capacity  revenues_usd  bookings
# 0          174.0       10631.1       240
# 1          174.0        5453.7       220
# 2          218.0       16161.0        79
# 3          174.0       10828.7        90
# 4          144.0       16721.6       209
# ...          ...           ...       ...
# 999713     144.0       14102.1        73
# 999714     168.0       32907.8       274
# 999715     218.0       13519.3       131
# 999716     144.0        8729.6       134
# 999717     144.0        3031.0       127
#
# [999718 rows x 20 columns]

# %%
display(data.describe())
print(data.describe().shape)
# Out:
#              level_0          index    Unnamed: 0  fligth_number  \
# count  999718.000000  999718.000000  9.997180e+05  999718.000000
# mean   499947.870237  499947.870237  6.437456e+05    6109.117706
# std    288642.978213  288642.978213  3.882671e+05    2050.918123
# min         0.000000       0.000000  0.000000e+00      10.000000
# 25%    249978.250000  249978.250000  3.116202e+05    5380.000000
# 50%    499950.500000  499950.500000  6.242615e+05    6036.000000
# 75%    749916.750000  749916.750000  9.457720e+05    7190.000000
# max    999889.000000  999889.000000  1.350331e+06    9264.000000
#
#             distance         noshow  denied_boarding     pax_midlow  \
# count  999718.000000  999718.000000    999718.000000  999718.000000
# mean     1460.855778       6.015700         0.047570      75.510574
# std      1684.637100       5.112556         0.547211      44.570278
# min        14.000000       0.000000         0.000000       0.000000
# 25%       538.000000       3.000000         0.000000      46.000000
# 50%       916.000000       5.000000         0.000000      77.000000
# 75%      1672.000000       8.000000         0.000000     104.000000
# max     11380.000000     271.000000        53.000000     344.000000
#
#             pax_high    pax_midhigh        pax_low  pax_freqflyer  \
# count  999718.000000  999718.000000  999718.000000  999718.000000
# mean        3.807903       6.319279      57.197498      16.798840
# std         7.251763      10.266169      38.398518      13.836479
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000      29.000000       7.000000
# 50%         1.000000       3.000000      55.000000      14.000000
# 75%         4.000000       8.000000      82.000000      23.000000
# max       195.000000     230.000000     296.000000     236.000000
#
#        group_bookings   out_of_stock        dom_cnx        int_cnx  \
# count   999718.000000  999718.000000  999718.000000  999718.000000
# mean         3.829329       0.096225      25.840142      26.708132
# std         12.299626       0.294900      32.263478      43.961292
# min          0.000000       0.000000       0.000000       0.000000
# 25%          0.000000       0.000000       0.000000       0.000000
# 50%          0.000000       0.000000      12.000000       5.000000
# 75%          0.000000       0.000000      42.000000      31.000000
# max        240.000000       1.000000     262.000000     357.000000
#
#                  p2p       capacity   revenues_usd       bookings
# count  999718.000000  999718.000000  999718.000000  999718.000000
# mean      107.085820     178.056066   14835.277687     159.634094
# std        65.524338      32.696178   17963.999498      68.630524
# min         0.000000      53.000000  -77206.900000       1.000000
# 25%        59.000000     150.000000    6286.200000     110.000000
# 50%        99.000000     174.000000    9692.200000     151.000000
# 75%       147.000000     174.000000   15730.900000     200.000000
# max       564.000000     451.000000  335775.400000     608.000000
# (8, 20)

# %% [markdown]
# sí
# fligth_number
# noshow
# denied_boarding
# dom
# int_cnx
# p2p
# capacity
# bookings
#
#
# No
# distance porque 2 podrian tener la misma
# rebenues
#
#
# analizar
# pax
# out of stock

# %%
#### Anlizando si 
#* pax_high
#* pax_midhigh
#* pax_midlow
#* pax_low
#* pax_freqflyer
#### están contenidas en bookings
datAnalisis1 = data[["Unnamed: 0","bookings"]]
datAnalisis1["suma"] = data["pax_high"] + data["pax_midhigh"] + data["pax_midlow"] + data["pax_low"] + data["pax_freqflyer"]

count = 0
for i in range(data.shape[0]):
    if (datAnalisis1["bookings"].iloc[i] != datAnalisis1["suma"].iloc[i]):
        print(datAnalisis1["bookings"].iloc[i])
    else: 
        count += 1
        
print("Hay:", count, "coincidencias", "de un total de", datAnalisis1.shape[0], "datos")

#### Conclusión: bookings contiene a esas variables.
# Out:
# C:\Users\sebad\AppData\Local\Temp\ipykernel_52660\3989490445.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Hay: 999718 coincidencias de un total de 999718 datos

# %%
#### Para optimizar el número de variables se unen los 2 pax_high y 2 pax_low
data['paxH'] = (data['pax_high'] + data['pax_midhigh'])
data['paxL'] = (data['pax_low'] + data['pax_midlow'])
data
# Out:
#         level_0   index  Unnamed: 0  fligth_number  distance  noshow  \
# 0             0       0      389083           8995      1394     9.0
# 1             1       1      177073           7061       489     0.0
# 2             2       2     1040357           8972      2180     4.0
# 3             3       3      505258           6039       524    13.0
# 4             4       4      369663           7713      1170    14.0
# ...         ...     ...         ...            ...       ...     ...
# 999713   999885  999885      359783           6024       552     5.0
# 999714   999886  999886      152315           6669      3934     4.0
# 999715   999887  999887     1000747           9094      1430     5.0
# 999716   999888  999888      117952           7704      1091     2.0
# 999717   999889  999889      305711           7746       283    10.0
#
#         denied_boarding  pax_midlow  pax_high  pax_midhigh  ...  \
# 0                     0          94         2           28  ...
# 1                     0         100         4            4  ...
# 2                     0           7         1            5  ...
# 3                     0          54         4            7  ...
# 4                     0          21        88           18  ...
# ...                 ...         ...       ...          ...  ...
# 999713                0          25        12           20  ...
# 999714                0         129         3           19  ...
# 999715                0           2         1            0  ...
# 999716                0          67         2            7  ...
# 999717                0          72         1            1  ...
#
#         group_bookings  out_of_stock  dom_cnx  int_cnx  p2p  capacity  \
# 0                   19             0        1        0  239     174.0
# 1                    0             0       19        9  192     174.0
# 2                    0             0        0       10   69     218.0
# 3                    0             0       26        0   64     174.0
# 4                   88             1       23        3  183     144.0
# ...                ...           ...      ...      ...  ...       ...
# 999713               0             0       64        9    0     144.0
# 999714              20             0        0      118  156     168.0
# 999715              36             0        7        0  124     218.0
# 999716               0             0       34        2   98     144.0
# 999717               0             0        5        3  119     144.0
#
#         revenues_usd  bookings  paxH  paxL
# 0            10631.1       240    30   188
# 1             5453.7       220     8   187
# 2            16161.0        79     6    71
# 3            10828.7        90    11    75
# 4            16721.6       209   106   103
# ...              ...       ...   ...   ...
# 999713       14102.1        73    32    29
# 999714       32907.8       274    22   250
# 999715       13519.3       131     1   110
# 999716        8729.6       134     9   109
# 999717        3031.0       127     2   123
#
# [999718 rows x 22 columns]

# %%
######## Anlizando la cantidad de vuelos que denegó abordajes.
data.loc[data.denied_boarding >= 1, 'sum_denied'] = 1
data.loc[data.denied_boarding < 1, 'sum_denied'] = 0
print(data['sum_denied'].sum(), 'vuelos')
# Out:
# 13779.0 vuelos

# %%
######## Anlizando la cantidad de vuelos que denegó abordajes.
data.loc[data.out_of_stock >= 1, 'sum_out_stock'] = 1
data.loc[data.denied_boarding < 1, 'sum_out_stock'] = 0
print(data['sum_out_stock'].sum(), 'vuelos')
# Out:
# 4440.0 vuelos

# %%
######## Anlizando la cantidad de vuelos que denegó abordajes.
data.loc[data.noshow >= 1, 'sum_noshow'] = 1
data.loc[data.noshow < 1, 'sum_noshow'] = 0
print(data['sum_noshow'].sum(), 'vuelos')
# Out:
# 928632.0 vuelos

# %%
dataUsar = data[['fligth_number', 'denied_boarding',
                 'dom_cnx', 'int_cnx', 'p2p', 'capacity',
                 'bookings', 'paxL', 'paxH',
                 'pax_freqflyer', 'group_bookings', 'noshow']]
dataUsar
# Out:
#         fligth_number  denied_boarding  dom_cnx  int_cnx  p2p  capacity  \
# 0                8995                0        1        0  239     174.0
# 1                7061                0       19        9  192     174.0
# 2                8972                0        0       10   69     218.0
# 3                6039                0       26        0   64     174.0
# 4                7713                0       23        3  183     144.0
# ...               ...              ...      ...      ...  ...       ...
# 999713           6024                0       64        9    0     144.0
# 999714           6669                0        0      118  156     168.0
# 999715           9094                0        7        0  124     218.0
# 999716           7704                0       34        2   98     144.0
# 999717           7746                0        5        3  119     144.0
#
#         bookings  paxL  paxH  pax_freqflyer  group_bookings  noshow
# 0            240   188    30             22              19     9.0
# 1            220   187     8             25               0     0.0
# 2             79    71     6              2               0     4.0
# 3             90    75    11              4               0    13.0
# 4            209   103   106              0              88    14.0
# ...          ...   ...   ...            ...             ...     ...
# 999713        73    29    32             12               0     5.0
# 999714       274   250    22              2              20     4.0
# 999715       131   110     1             20              36     5.0
# 999716       134   109     9             16               0     2.0
# 999717       127   123     2              2               0    10.0
#
# [999718 rows x 12 columns]

# %%
#Creando un objeto KNN con las condiciones iniciales
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier(n_neighbors=3,weights="uniform")
#El objeto ha sido creado

#Entrenando el modelo con los datos de iris
KNN=KNN.fit(X_train,y_train)

#Aplicando el modelo a otros datos
resultado=KNN.predict(X_test)
print("Resultado de la predicción:\n",resultado)
print("Resultado original:\n",y_test)

#Aplicando el modelo a otros datos
resultado=KNN.predict_proba(X_test)
print("Resultado de la predicción:\n",resultado)

#Aplicando el modelo a otros datos
vecinos=KNN.kneighbors(X_test[0:2,:],3,True)
print("Resultado de los vecinos cercanos:\n",vecinos)

#Observando los labels de los vecinos más cecanos
print(y_train[vecinos[1]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\sebad\OneDrive - Universidad Adolfo Ibanez\Code\Métodos de Aprendizaje Automático\Tareas\Tarea2\Tarea2-2.ipynb Celda 22 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/sebad/OneDrive%20-%20Universidad%20Adolfo%20Ibanez/Code/M%C3%A9todos%20de%20Aprendizaje%20Autom%C3%A1tico/Tareas/Tarea2/Tarea2-2.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a> KNN = KNeighborsClassifier(n_neighbors=3,weights="uniform")
#       <a href='vscode-notebook-cell:/c%3A/Users/sebad/OneDrive%20-%20Universidad%20Adolfo%20Ibanez/Code/M%C3%A9todos%20de%20Aprendizaje%20Autom%C3%A1tico/Tareas/Tarea2/Tarea2-2.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a> #El objeto ha sido creado
#       <a href='vscode-notebook-cell:/c%3A/Users/sebad/OneDrive%20-%20Universidad%20Adolfo%20Ibanez/Code/M%C3%A9todos%20de%20Aprendizaje%20Autom%C3%A1tico/Tareas/Tarea2/Tarea2-2.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a>
#       <a href='vscode-notebook-cell:/c%3A/Users/sebad/OneDrive%20-%20Universidad%20Adolfo%20Ibanez/Code/M%C3%A9todos%20de%20Aprendizaje%20Autom%C3%A1tico/Tareas/Tarea2/Tarea2-2.ipynb#X26sZmlsZQ%3D%3D?line=5'>6</a> #Entrenando el modelo con los datos de iris
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sebad/OneDrive%20-%20Universidad%20Adolfo%20Ibanez/Code/M%C3%A9todos%20de%20Aprendizaje%20Autom%C3%A1tico/Tareas/Tarea2/Tarea2-2.ipynb#X26sZmlsZQ%3D%3D?line=6'>7</a> KNN=KNN.fit(X_train,y_train)
#       <a href='vscode-notebook-cell:/c%3A/Users/sebad/OneDrive%20-%20Universidad%20Adolfo%20Ibanez/Code/M%C3%A9todos%20de%20Aprendizaje%20Autom%C3%A1tico/Tareas/Tarea2/Tarea2-2.ipynb#X26sZmlsZQ%3D%3D?line=8'>9</a> #Aplicando el modelo a otros datos
#      <a href='vscode-notebook-cell:/c%3A/Users/sebad/OneDrive%20-%20Universidad%20Adolfo%20Ibanez/Code/M%C3%A9todos%20de%20Aprendizaje%20Autom%C3%A1tico/Tareas/Tarea2/Tarea2-2.ipynb#X26sZmlsZQ%3D%3D?line=9'>10</a> resultado=KNN.predict(X_test)
#
# NameError: name 'X_train' is not defined

# %%
kf = KFold(n_splits=10,shuffle=False)
print(kf)
#Generando los k-fold
temp = kf.split(dataUsar)
count = 0

for train_index, test_index in temp:
    
    print('')
    print(count)
    count += 1
    
    lista_train_index = list(train_index)
    lista_test_index = list(test_index)
    
    X_train = dataUsar.iloc[lista_train_index,0:11]
    y_train = dataUsar.iloc[lista_train_index,11]
    
    X_test = dataUsar.iloc[lista_test_index,0:11]
    y_test = dataUsar.iloc[lista_test_index,11]
    
    
    KNN = KNeighborsClassifier(n_neighbors=3,weights="uniform")



    KNN=KNN.fit(X_train,y_train)
    
    
    #Aplicando el modelo a otros datos
    resultado = KNN.predict(X_test)
    print("Resultado de la predicción:\n",resultado)
    print("Resultado original:\n",y_test)
# Out:
# KFold(n_splits=10, random_state=None, shuffle=False)
#
# 0
# Resultado de la predicción:
#  [4. 0. 2. ... 1. 2. 2.]
# Resultado original:
#  0         9.0
# 1         0.0
# 2         4.0
# 3        13.0
# 4        14.0
#          ...
# 99967     9.0
# 99968     8.0
# 99969     5.0
# 99970     3.0
# 99971     5.0
# Name: noshow, Length: 99972, dtype: float64
#
# 1
# Resultado de la predicción:
#  [0. 0. 2. ... 0. 5. 5.]
# Resultado original:
#  99972      4.0
# 99973      2.0
# 99974     11.0
# 99975      4.0
# 99976      0.0
#           ...
# 199939     5.0
# 199940     5.0
# 199941     0.0
# 199942     4.0
# 199943     6.0
# Name: noshow, Length: 99972, dtype: float64
#
# 2
# Resultado de la predicción:
#  [2. 8. 2. ... 1. 6. 0.]
# Resultado original:
#  199944     6.0
# 199945    17.0
# 199946     9.0
# 199947     4.0
# 199948     1.0
#           ...
# 299911     3.0
# 299912     5.0
# 299913     7.0
# 299914     3.0
# 299915     1.0
# Name: noshow, Length: 99972, dtype: float64
#
# 3
# Resultado de la predicción:
#  [2. 4. 7. ... 2. 1. 2.]
# Resultado original:
#  299916     4.0
# 299917     6.0
# 299918    12.0
# 299919    17.0
# 299920     2.0
#           ...
# 399883    15.0
# 399884     3.0
# 399885    16.0
# 399886    13.0
# 399887     3.0
# Name: noshow, Length: 99972, dtype: float64
#
# 4
# Resultado de la predicción:
#  [ 3.  5.  9. ... 10.  5.  9.]
# Resultado original:
#  399888     5.0
# 399889    10.0
# 399890     6.0
# 399891     3.0
# 399892     5.0
#           ...
# 499855     8.0
# 499856     1.0
# 499857     5.0
# 499858     6.0
# 499859     8.0
# Name: noshow, Length: 99972, dtype: float64
#
# 5
# Resultado de la predicción:
#  [2. 0. 1. ... 7. 6. 3.]
# Resultado original:
#  499860     7.0
# 499861    11.0
# 499862     5.0
# 499863    12.0
# 499864     8.0
#           ...
# 599827    10.0
# 599828     4.0
# 599829     2.0
# 599830     6.0
# 599831     5.0
# Name: noshow, Length: 99972, dtype: float64
#
# 6
# Resultado de la predicción:
#  [3. 4. 3. ... 2. 0. 4.]
# Resultado original:
#  599832    11.0
# 599833     1.0
# 599834    16.0
# 599835     6.0
# 599836    13.0
#           ...
# 699799     0.0
# 699800     2.0
# 699801     5.0
# 699802     3.0
# 699803     4.0
# Name: noshow, Length: 99972, dtype: float64
#
# 7
# Resultado de la predicción:
#  [3. 0. 2. ... 5. 3. 4.]
# Resultado original:
#  699804    11.0
# 699805     1.0
# 699806     0.0
# 699807     4.0
# 699808     5.0
#           ...
# 799771    16.0
# 799772    11.0
# 799773     1.0
# 799774    21.0
# 799775     7.0
# Name: noshow, Length: 99972, dtype: float64
#
# 8
# Resultado de la predicción:
#  [3. 4. 3. ... 9. 2. 3.]
# Resultado original:
#  799776     4.0
# 799777     2.0
# 799778    10.0
# 799779     8.0
# 799780     3.0
#           ...
# 899742     1.0
# 899743     5.0
# 899744     3.0
# 899745     4.0
# 899746     6.0
# Name: noshow, Length: 99971, dtype: float64
#
# 9
# Resultado de la predicción:
#  [1. 3. 5. ... 5. 3. 0.]
# Resultado original:
#  899747     3.0
# 899748     5.0
# 899749    28.0
# 899750     2.0
# 899751     5.0
#           ...
# 999713     5.0
# 999714     4.0
# 999715     5.0
# 999716     2.0
# 999717    10.0
# Name: noshow, Length: 99971, dtype: float64

# %%
scaler = StandardScaler()
scaler.fit(dataUsar)

data_estandar = pd.DataFrame(scaler.transform(dataUsar), columns=dataUsar.columns)
data_estandar
# Out:
#         fligth_number  denied_boarding   dom_cnx   int_cnx       p2p  \
# 0            1.407118        -0.086933 -0.769916 -0.607538  2.013210
# 1            0.464125        -0.086933 -0.212009 -0.402812  1.295919
# 2            1.395903        -0.086933 -0.800910 -0.380065 -0.581247
# 3           -0.034188        -0.086933  0.004955 -0.607538 -0.657555
# 4            0.782032        -0.086933 -0.088030 -0.539296  1.158565
# ...               ...              ...       ...       ...       ...
# 999713      -0.041502        -0.086933  1.182758 -0.402812 -1.634292
# 999714       0.272991        -0.086933 -0.800910  2.076643  0.746504
# 999715       1.455389        -0.086933 -0.583947 -0.607538  0.258136
# 999716       0.777643        -0.086933  0.252913 -0.562043 -0.138663
# 999717       0.798122        -0.086933 -0.645936 -0.539296  0.181828
#
#         capacity  bookings      paxL      paxH  pax_freqflyer  group_bookings  \
# 0      -0.124053  1.170994  0.830775  1.398776       0.375902        1.233426
# 1      -0.124053  0.879579  0.815749 -0.149725       0.592720       -0.311337
# 2       1.221670 -1.174902 -0.927179 -0.290497      -1.069553       -0.311337
# 3      -0.124053 -1.014623 -0.867078  0.061435      -0.925007       -0.311337
# 4      -1.041592  0.719300 -0.446371  6.748140      -1.214098        6.843356
# ...          ...       ...       ...       ...            ...             ...
# 999713 -1.041592 -1.262327 -1.558239  1.539548      -0.346825       -0.311337
# 999714 -0.307561  1.666401  1.762340  0.835685      -1.069553        1.314729
# 999715  1.221670 -0.417221 -0.341194 -0.642429       0.231357        2.615583
# 999716 -1.041592 -0.373509 -0.356220 -0.079338      -0.057734       -0.311337
# 999717 -1.041592 -0.475504 -0.145866 -0.572043      -1.069553       -0.311337
#
#           noshow
# 0       0.583720
# 1      -1.176653
# 2      -0.394265
# 3       1.366108
# 4       1.561705
# ...          ...
# 999713 -0.198668
# 999714 -0.394265
# 999715 -0.198668
# 999716 -0.785459
# 999717  0.779317
#
# [999718 rows x 12 columns]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsRegressor
import matplotlib.pyplot as plt

X = data_estandar.iloc[:, :-1].values  # Todas las columnas menos la última
y = data_estandar.iloc[:, -1].values   # Solo la última columna

mean_squared_errors = []

for k in range(1, 26):
    knn = KNeighborsRegressor(n_neighbors=k)
    mse = cross_val_score(knn, X, y, scoring='neg_mean_squared_error', cv=10) #folds 10
    mean_squared_errors.append(-mse.mean())

plt.figure(figsize=(12, 6))
plt.plot(range(1, 26), mean_squared_errors, color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Mean Squared Error vs. K Value')
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Mean Squared Error')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\sebad\OneDrive - Universidad Adolfo Ibanez\Code\Métodos de Aprendizaje Automático\Tareas\Tarea2\Tarea2-2.ipynb Celda 26 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/sebad/OneDrive%20-%20Universidad%20Adolfo%20Ibanez/Code/M%C3%A9todos%20de%20Aprendizaje%20Autom%C3%A1tico/Tareas/Tarea2/Tarea2-2.ipynb#X32sZmlsZQ%3D%3D?line=9'>10</a> for k in range(1, 26):
#      <a href='vscode-notebook-cell:/c%3A/Users/sebad/OneDrive%20-%20Universidad%20Adolfo%20Ibanez/Code/M%C3%A9todos%20de%20Aprendizaje%20Autom%C3%A1tico/Tareas/Tarea2/Tarea2-2.ipynb#X32sZmlsZQ%3D%3D?line=10'>11</a>     knn = KNeighborsRegressor(n_neighbors=k)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/sebad/OneDrive%20-%20Universidad%20Adolfo%20Ibanez/Code/M%C3%A9todos%20de%20Aprendizaje%20Autom%C3%A1tico/Tareas/Tarea2/Tarea2-2.ipynb#X32sZmlsZQ%3D%3D?line=11'>12</a>     mse = cross_val_score(knn, X, y, scoring='neg_mean_squared_error', cv=10) #folds 10
#      <a href='vscode-notebook-cell:/c%3A/Users/sebad/OneDrive%20-%20Universidad%20Adolfo%20Ibanez/Code/M%C3%A9todos%20de%20Aprendizaje%20Autom%C3%A1tico/Tareas/Tarea2/Tarea2-2.ipynb#X32sZmlsZQ%3D%3D?line=12'>13</a>     mean_squared_errors.append(-mse.mean())
#      <a href='vscode-notebook-cell:/c%3A/Users/sebad/OneDrive%20-%20Universidad%20Adolfo%20Ibanez/Code/M%C3%A9todos%20de%20Aprendizaje%20Autom%C3%A1tico/Tareas/Tarea2/Tarea2-2.ipynb#X32sZmlsZQ%3D%3D?line=14'>15</a> plt.figure(figsize=(12, 6))
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:562, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     559 # To ensure multimetric format is not supported
#     560 scorer = check_scoring(estimator, scoring=scoring)
# --> 562 cv_results = cross_validate(
#     563     estimator=estimator,
#     564     X=X,
#     565     y=y,
#     566     groups=groups,
#     567     scoring={"score": scorer},
#     568     cv=cv,
#     569     n_jobs=n_jobs,
#     570     verbose=verbose,
#     571     fit_params=fit_params,
#     572     pre_dispatch=pre_dispatch,
#     573     error_score=error_score,
#     574 )
#     575 return cv_results["test_score"]
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:309, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     306 # We clone the estimator to make sure that all the folds are
#     307 # independent, and that it is pickle-able.
#     308 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 309 results = parallel(
#     310     delayed(_fit_and_score)(
#     311         clone(estimator),
#     312         X,
#     313         y,
#     314         scorers,
#     315         train,
#     316         test,
#     317         verbose,
#     318         None,
#     319         fit_params,
#     320         return_train_score=return_train_score,
#     321         return_times=True,
#     322         return_estimator=return_estimator,
#     323         error_score=error_score,
#     324     )
#     325     for train, test in indices
#     326 )
#     328 _warn_or_raise_about_fit_failures(results, error_score)
#     330 # For callable scoring, the return type is only know after calling. If the
#     331 # return type is a dictionary, the error scores can now be inserted with
#     332 # the correct key.
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\joblib\parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:754, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     751 result["fit_error"] = None
#     753 fit_time = time.time() - start_time
# --> 754 test_scores = _score(estimator, X_test, y_test, scorer, error_score)
#     755 score_time = time.time() - start_time - fit_time
#     756 if return_train_score:
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:813, in _score(estimator, X_test, y_test, scorer, error_score)
#     811         scores = scorer(estimator, X_test)
#     812     else:
# --> 813         scores = scorer(estimator, X_test, y_test)
#     814 except Exception:
#     815     if isinstance(scorer, _MultimetricScorer):
#     816         # If `_MultimetricScorer` raises exception, the `error_score`
#     817         # parameter is equal to "raise".
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py:136, in _MultimetricScorer.__call__(self, estimator, *args, **kwargs)
#     134 try:
#     135     if isinstance(scorer, _BaseScorer):
# --> 136         score = scorer._score(
#     137             cached_call, estimator, *args, **routed_params.get(name).score
#     138         )
#     139     else:
#     140         score = scorer(estimator, *args, **routed_params.get(name).score)
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py:353, in _PredictScorer._score(self, method_caller, estimator, X, y_true, **kwargs)
#     316 """Evaluate predicted target values for X relative to y_true.
#     317
#     318 Parameters
#    (...)
#     343     Score function applied to prediction of estimator on X.
#     344 """
#     345 self._warn_overlap(
#     346     message=(
#     347         "There is an overlap between set kwargs of this scorer instance and"
#    (...)
#     351     kwargs=kwargs,
#     352 )
# --> 353 y_pred = method_caller(estimator, "predict", X)
#     354 scoring_kwargs = {**self._kwargs, **kwargs}
#     355 return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py:86, in _cached_call(cache, estimator, response_method, *args, **kwargs)
#      83 if cache is not None and response_method in cache:
#      84     return cache[response_method]
# ---> 86 result, _ = _get_response_values(
#      87     estimator, *args, response_method=response_method, **kwargs
#      88 )
#      90 if cache is not None:
#      91     cache[response_method] = result
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\sklearn\utils\_response.py:109, in _get_response_values(estimator, X, response_method, pos_label)
#     102     if response_method != "predict":
#     103         raise ValueError(
#     104             f"{estimator.__class__.__name__} should either be a classifier to be "
#     105             f"used with response_method={response_method} or the response_method "
#     106             "should be 'predict'. Got a regressor with response_method="
#     107             f"{response_method} instead."
#     108         )
# --> 109     y_pred, pos_label = estimator.predict(X), None
#     111 return y_pred, pos_label
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\sklearn\neighbors\_regression.py:237, in KNeighborsRegressor.predict(self, X)
#     221 """Predict the target for the provided data.
#     222
#     223 Parameters
#    (...)
#     232     Target values.
#     233 """
#     234 if self.weights == "uniform":
#     235     # In that case, we do not need the distances to perform
#     236     # the weighting so we do not compute them.
# --> 237     neigh_ind = self.kneighbors(X, return_distance=False)
#     238     neigh_dist = None
#     239 else:
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\sklearn\neighbors\_base.py:877, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     871     if issparse(X):
#     872         raise ValueError(
#     873             "%s does not work with sparse matrices. Densify the data, "
#     874             "or set algorithm='brute'"
#     875             % self._fit_method
#     876         )
# --> 877     chunked_results = Parallel(n_jobs, prefer="threads")(
#     878         delayed(_tree_query_parallel_helper)(
#     879             self._tree, X[s], n_neighbors, return_distance
#     880         )
#     881         for s in gen_even_slices(X.shape[0], n_jobs)
#     882     )
#     883 else:
#     884     raise ValueError("internal: _fit_method not recognized")
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\joblib\parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File c:\Users\sebad\anaconda3\Lib\site-packages\sklearn\neighbors\_base.py:683, in _tree_query_parallel_helper(tree, *args, **kwargs)
#     677 def _tree_query_parallel_helper(tree, *args, **kwargs):
#     678     """Helper for the Parallel calls in KNeighborsMixin.kneighbors.
#     679
#     680     The Cython method tree.query is not directly picklable by cloudpickle
#     681     under PyPy.
#     682     """
# --> 683     return tree.query(*args, **kwargs)
#
# KeyboardInterrupt:
